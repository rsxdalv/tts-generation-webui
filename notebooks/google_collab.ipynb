# %%
# !git clone https://github.com/rsxdalv/tts-generation-webui

# %%
import os
os.chdir("./tts-generation-webui")

# %%
# Run install/updates
# !git pull
# !pip install -r requirements.txt
# !python update.py

# %%
# Tortoise might not be compatible with the latest version of transformers.
# You can try to install an older version of transformers:
# !pip install transformers==4.29.2
# Meanwhile, audiocraft requires the latest version of transformers.
# You can try to install the latest version of transformers:
# !pip install transformers==4.31.0

# %%
# !python server.py --share
